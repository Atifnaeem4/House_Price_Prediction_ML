# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset = pd.read_csv("house_data.csv")

# %%
dataset.head()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# 1             2570      7242     2.0           0     0  ...      7
# 2              770     10000     1.0           0     0  ...      6
# 3             1960      5000     1.0           0     0  ...      7
# 4             1680      8080     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %%
dataset.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
dataset.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# std    4.142051e+04      0.539989      0.086517      0.766318      0.650743
# min    5.200000e+02      1.000000      0.000000      0.000000      1.000000
# 25%    5.040000e+03      1.000000      0.000000      0.000000      3.000000
# 50%    7.618000e+03      1.500000      0.000000      0.000000      3.000000
# 75%    1.068800e+04      2.000000      0.000000      0.000000      4.000000
# max    1.651359e+06      3.500000      1.000000      4.000000      5.000000
#
#               grade    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       7.656873   1788.390691     291.509045   1971.005136     84.402258
# std        1.175459    828.090978     442.575043     29.373411    401.679240
# min        1.000000    290.000000       0.000000   1900.000000      0.000000
# 25%        7.000000   1190.000000       0.000000   1951.000000      0.000000
# 50%        7.000000   1560.000000       0.000000   1975.000000      0.000000
# 75%        8.000000   2210.000000     560.000000   1997.000000      0.000000
# max       13.000000   9410.000000    4820.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21613.000000  21613.000000  21613.000000   21613.000000   21613.000000
# mean   98077.939805     47.560053   -122.213896    1986.552492   12768.455652
# std       53.505026      0.138564      0.140828     685.391304   27304.179631
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471000   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.230000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %%
plt.style.use('seaborn')

# %%
dataset['bedrooms'].value_counts().plot(kind='bar')
plt.title('number of Bedroom')
plt.xlabel('Bedrooms')
plt.ylabel('Count')
sns.despine
# Out:
# <function seaborn.utils.despine(fig=None, ax=None, top=True, right=True, left=False, bottom=False, offset=None, trim=False)>

# %%
plt.scatter(dataset.price,dataset.sqft_living,color='r')
plt.title("Price vs Square Feet")
plt.xlabel('Price')
plt.ylabel('SquareFeet')
# Out:
# Text(0, 0.5, 'SquareFeet')

# %%
plt.scatter(dataset.price,dataset.long,color='teal')
plt.title("Price vs Location of the area")
plt.xlabel('Price')
plt.ylabel('Location of the Area')
# Out:
# Text(0, 0.5, 'Location of the Area')

# %%
plt.scatter(dataset.price,dataset.lat,color='g')
plt.xlabel("Price")
plt.ylabel('Latitude')
plt.title("Latitude vs Price")
# Out:
# Text(0.5, 1.0, 'Latitude vs Price')

# %%
train1 = dataset.drop(['id'],axis=1)
train1.head()
# Out:
#               date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  20141013T000000  221900.0         3       1.00         1180      5650
# 1  20141209T000000  538000.0         3       2.25         2570      7242
# 2  20150225T000000  180000.0         2       1.00          770     10000
# 3  20141209T000000  604000.0         4       3.00         1960      5000
# 4  20150218T000000  510000.0         3       2.00         1680      8080
#
#    floors  waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0     1.0           0     0          3      7        1180              0
# 1     2.0           0     0          3      7        2170            400
# 2     1.0           0     0          3      6         770              0
# 3     1.0           0     0          5      7        1050            910
# 4     1.0           0     0          3      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503

# %%
conv_dates = [1 if values == 2014 else 0 for values in dataset.date ]
train1['date'] = conv_dates
train1
# Out:
#        date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0         0  221900.0         3       1.00         1180      5650     1.0
# 1         0  538000.0         3       2.25         2570      7242     2.0
# 2         0  180000.0         2       1.00          770     10000     1.0
# 3         0  604000.0         4       3.00         1960      5000     1.0
# 4         0  510000.0         3       2.00         1680      8080     1.0
# ...     ...       ...       ...        ...          ...       ...     ...
# 21608     0  360000.0         3       2.50         1530      1131     3.0
# 21609     0  400000.0         4       2.50         2310      5813     2.0
# 21610     0  402101.0         2       0.75         1020      1350     2.0
# 21611     0  400000.0         3       2.50         1600      2388     2.0
# 21612     0  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# 1               0     0          3      7        2170            400
# 2               0     0          3      6         770              0
# 3               0     0          5      7        1050            910
# 4               0     0          3      8        1680              0
# ...           ...   ...        ...    ...         ...            ...
# 21608           0     0          3      8        1530              0
# 21609           0     0          3      8        2310              0
# 21610           0     0          3      7        1020              0
# 21611           0     0          3      8        1600              0
# 21612           0     0          3      7        1020              0
#
#        yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0          1955             0    98178  47.5112 -122.257           1340
# 1          1951          1991    98125  47.7210 -122.319           1690
# 2          1933             0    98028  47.7379 -122.233           2720
# 3          1965             0    98136  47.5208 -122.393           1360
# 4          1987             0    98074  47.6168 -122.045           1800
# ...         ...           ...      ...      ...      ...            ...
# 21608      2009             0    98103  47.6993 -122.346           1530
# 21609      2014             0    98146  47.5107 -122.362           1830
# 21610      2009             0    98144  47.5944 -122.299           1020
# 21611      2004             0    98027  47.5345 -122.069           1410
# 21612      2008             0    98144  47.5941 -122.299           1020
#
#        sqft_lot15
# 0            5650
# 1            7639
# 2            8062
# 3            5000
# 4            7503
# ...           ...
# 21608        1509
# 21609        7200
# 21610        2007
# 21611        1287
# 21612        1357
#
# [21613 rows x 20 columns]

# %%
dataset.floors.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
plt.scatter(dataset.zipcode,dataset.price)
plt.title("Which is the pricey location by zipcode?")
# Out:
# Text(0.5, 1.0, 'Which is the pricey location by zipcode?')

# %%
plt.scatter(dataset.floors,dataset.price)

# %%
plt.scatter(dataset.condition,dataset.price)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
variables=train1[['date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors','waterfront', 'view', 'condition', 'grade', 'sqft_above','sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long','sqft_living15', 'sqft_lot15']]     
#we are taking as a list of all feature variable

# %%
vif=pd.DataFrame()
vif["VIF"]=[variance_inflation_factor(variables.values,i) for i in  range(variables.shape[1])]
vif["Features"]=variables.columns
vif
# Out:
# C:\Users\jazza\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1717: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.uncentered_tss
# C:\Users\jazza\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#              VIF       Features
# 0            NaN           date
# 1   2.327239e+01       bedrooms
# 2   2.861188e+01      bathrooms
# 3            inf    sqft_living
# 4   2.377656e+00       sqft_lot
# 5   1.689222e+01         floors
# 6   1.212827e+00     waterfront
# 7   1.551834e+00           view
# 8   3.471167e+01      condition
# 9   1.473809e+02          grade
# 10           inf     sqft_above
# 11           inf  sqft_basement
# 12  9.588180e+03       yr_built
# 13  1.195015e+00   yr_renovated
# 14  1.630845e+06        zipcode
# 15  1.390263e+05            lat
# 16  1.359553e+06           long
# 17  2.710315e+01  sqft_living15
# 18  2.598758e+00     sqft_lot15

# %%
data_no_multicollinearity=train1.drop(['yr_built'],axis=1)
data_no_multicollinearity
# Out:
#        date     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  \
# 0         0  221900.0         3       1.00         1180      5650     1.0
# 1         0  538000.0         3       2.25         2570      7242     2.0
# 2         0  180000.0         2       1.00          770     10000     1.0
# 3         0  604000.0         4       3.00         1960      5000     1.0
# 4         0  510000.0         3       2.00         1680      8080     1.0
# ...     ...       ...       ...        ...          ...       ...     ...
# 21608     0  360000.0         3       2.50         1530      1131     3.0
# 21609     0  400000.0         4       2.50         2310      5813     2.0
# 21610     0  402101.0         2       0.75         1020      1350     2.0
# 21611     0  400000.0         3       2.50         1600      2388     2.0
# 21612     0  325000.0         2       0.75         1020      1076     2.0
#
#        waterfront  view  condition  grade  sqft_above  sqft_basement  \
# 0               0     0          3      7        1180              0
# 1               0     0          3      7        2170            400
# 2               0     0          3      6         770              0
# 3               0     0          5      7        1050            910
# 4               0     0          3      8        1680              0
# ...           ...   ...        ...    ...         ...            ...
# 21608           0     0          3      8        1530              0
# 21609           0     0          3      8        2310              0
# 21610           0     0          3      7        1020              0
# 21611           0     0          3      8        1600              0
# 21612           0     0          3      7        1020              0
#
#        yr_renovated  zipcode      lat     long  sqft_living15  sqft_lot15
# 0                 0    98178  47.5112 -122.257           1340        5650
# 1              1991    98125  47.7210 -122.319           1690        7639
# 2                 0    98028  47.7379 -122.233           2720        8062
# 3                 0    98136  47.5208 -122.393           1360        5000
# 4                 0    98074  47.6168 -122.045           1800        7503
# ...             ...      ...      ...      ...            ...         ...
# 21608             0    98103  47.6993 -122.346           1530        1509
# 21609             0    98146  47.5107 -122.362           1830        7200
# 21610             0    98144  47.5944 -122.299           1020        2007
# 21611             0    98027  47.5345 -122.069           1410        1287
# 21612             0    98144  47.5941 -122.299           1020        1357
#
# [21613 rows x 19 columns]

# %%
variables=train1[['date', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot', 'floors','waterfront', 'view', 'condition', 'grade', 'sqft_above','sqft_basement', 'yr_renovated', 'zipcode', 'lat','sqft_living15', 'sqft_lot15']]     
#calculating vif this tme without yr_built column
vif=pd.DataFrame()
vif["VIF"]=[variance_inflation_factor(variables.values,i) for i in  range(variables.shape[1])]
vif["Features"]=variables.columns
vif
# Out:
# C:\Users\jazza\Anaconda3\lib\site-packages\statsmodels\regression\linear_model.py:1717: RuntimeWarning: invalid value encountered in double_scalars
#   return 1 - self.ssr/self.uncentered_tss
# C:\Users\jazza\Anaconda3\lib\site-packages\statsmodels\stats\outliers_influence.py:193: RuntimeWarning: divide by zero encountered in double_scalars
#   vif = 1. / (1. - r_squared_i)
#              VIF       Features
# 0            NaN           date
# 1   2.319722e+01       bedrooms
# 2   2.509961e+01      bathrooms
# 3            inf    sqft_living
# 4   2.367323e+00       sqft_lot
# 5   1.638785e+01         floors
# 6   1.212179e+00     waterfront
# 7   1.520641e+00           view
# 8   3.158859e+01      condition
# 9   1.393981e+02          grade
# 10           inf     sqft_above
# 11           inf  sqft_basement
# 12  1.074874e+00   yr_renovated
# 13  1.322492e+05        zipcode
# 14  1.331085e+05            lat
# 15  2.647374e+01  sqft_living15
# 16  2.576852e+00     sqft_lot15

# %%
x=data_no_multicollinearity.drop('price',axis=1)

y=data_no_multicollinearity['price']

# %%
##Training and Testing split

from sklearn.model_selection import train_test_split
x_train, x_test, y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred1=lr.predict(x_test)

# %%
y_pred1
# Out:
# array([ 433101.37983202, 1516895.25104876,  464799.54884609, ...,
#         340064.19605559,  141940.43797819,  396622.05781471])

# %%
y_test
# Out:
# 17384     297000.0
# 722      1578000.0
# 2680      562100.0
# 18754     631500.0
# 14554     780000.0
#            ...
# 5427      844000.0
# 16547     335500.0
# 4585      369950.0
# 17762     300000.0
# 16323     575950.0
# Name: price, Length: 4323, dtype: float64

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
r_squared1=r2_score(y_test,y_pred1)
r_squared1
# Out:
# 0.6740800739927849

# %%
mse1=mean_squared_error(y_test,y_pred1)
mse1
# Out:
# 38759789049.62586

# %% [markdown]
# ### Decision Tree Regression

# %%
from sklearn.tree import DecisionTreeRegressor, plot_tree
dr=DecisionTreeRegressor(random_state=0)
dr.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
y_pred2=dr.predict(x_test)
y_pred2
# Out:
# array([ 288000., 1680000.,  459500., ...,  419500.,  150000.,  475000.])

# %%
y_test
# Out:
# 17384     297000.0
# 722      1578000.0
# 2680      562100.0
# 18754     631500.0
# 14554     780000.0
#            ...
# 5427      844000.0
# 16547     335500.0
# 4585      369950.0
# 17762     300000.0
# 16323     575950.0
# Name: price, Length: 4323, dtype: float64

# %%
mse2=mean_squared_error(y_test,y_pred2)
mse2
# Out:
# 26910048109.793606

# %%
r_squared2=r2_score(y_test,y_pred2)
r_squared2
# Out:
# 0.7737211397728392

# %% [markdown]
# ### RandomForestRegression

# %%
from sklearn.ensemble import RandomForestRegressor
rf=RandomForestRegressor()
rf.fit(x_train,y_train)
y_pred3=rf.predict(x_test)

# %%
y_pred3
# Out:
# array([ 305088.6       , 1692174.4       ,  528159.67666667, ...,
#         413049.47      ,  224277.75      ,  484584.4       ])

# %%
y_test
# Out:
# 17384     297000.0
# 722      1578000.0
# 2680      562100.0
# 18754     631500.0
# 14554     780000.0
#            ...
# 5427      844000.0
# 16547     335500.0
# 4585      369950.0
# 17762     300000.0
# 16323     575950.0
# Name: price, Length: 4323, dtype: float64

# %%
r_squared3=r2_score(y_test,y_pred3)
r_squared3
# Out:
# 0.8945127473512899

# %%
mse3=mean_squared_error(y_test,y_pred3)
mse3
# Out:
# 12544994441.358807

# %%
plt.figure(figsize=(11,5)) 
x=[mse1,mse2,mse3]
y=['Linear Regression','Decision Tree Regression','Random Forest Regression']

plt.bar(y,x, color="#444444")
plt.xlabel('ML Algorithms')
plt.ylabel('Mean Square Error')
plt.title('Mean Square Error of various Algo')
# Out:
# Text(0.5, 1.0, 'Mean Square Error of various Algo')

# %%
plt.figure(figsize=(12,6)) 
x=[r_squared1,r_squared2,r_squared3]
y=['Linear Regression','Decision Tree Regression','Random Forest Regression']

plt.bar(y,x, color="#444444")
plt.xlabel('ML Algorithms')
plt.ylabel('R Sqaured value')
plt.title('R Sqaured value of various Algo')
# Out:
# Text(0.5, 1.0, 'R Sqaured value of various Algo')

# %%
#R-squared is a statistical measure that represents the goodness of fit of a regression model. 
#The ideal value for r-square is 1. The closer the value of r-square to 1, the better is the model fitted. 

#A value close to zero will represent better quality of the estimator / predictor (regression model). 
#An MSE of zero (0) represents the fact that the predictor is a perfect predictor.

# %% [markdown]
# #### Since, the Random Forest Regression is showing minimum Mean Square Error and maximum R Square Value among all the regression algorithm, hence, Random Forest Regression fits best for our model..
